# %% [markdown]
# <a href="https://colab.research.google.com/github/SabrinaSchulz/HelloWorld/blob/gitHub/Datei_zum_Testen_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Neues Projekt zum Test von der Verkünpfung von Colab und GitHub
