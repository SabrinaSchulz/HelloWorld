# %% [markdown]
# <a href="https://colab.research.google.com/github/SabrinaSchulz/HelloWorld/blob/gitHub/Datei_zum_Testen_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Überschrift zum Testen

# %% [markdown]
# Neues Projekt zum Test von der Verkünpfung von Colab und GitHub

# %% [markdown]
# Man kann Bilder im GitHub Reposiory speichern und per Link öffnen.

# %%
import requests
from io import BytesIO
from PIL import Image
url = 'https://raw.githubusercontent.com/SabrinaSchulz/HelloWorld/images/P36240.jpg'
page = requests.get(url)
Image.open(BytesIO(page.content))
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1772x1309 at 0x7F4341C754D0>

# %% [markdown]
# Man kann den Inhalt eines Git Branches in einen Ordner klonen. Hier wird der Branch "HelloWorld" in den Odner content/HelloWorld geklont:

# %%
# !git clone https://github.com/SabrinaSchulz/HelloWorld.git HelloWorld
from PIL import Image
# Out:
# Cloning into 'HelloWorld'...
# remote: Enumerating objects: 34, done.
# remote: Counting objects: 100% (34/34), done.
# remote: Compressing objects: 100% (30/30), done.
# remote: Total 34 (delta 5), reused 0 (delta 0), pack-reused 0
# Unpacking objects: 100% (34/34), done.

# %% [markdown]
# Zu einem anderen Branch wechseln und diesen "auschecken":

# %%
# !cd images && git checkout images
# Out:
# Already on 'images'
# Your branch is up to date with 'origin/images'.

# %%
# !git clone -branch images ['test 123']
# Out:
# Cloning into '[test 123]'...
# fatal: Remote branch ranch not found in upstream origin
# fatal: The remote end hung up unexpectedly

# %%
# !ls
# Out:
# Bilder	HelloWorld  images  sample_data  Test

# %%
# !unzip folder.zip /content/images/
# Out:
# Archive:  folder.zip
#   End-of-central-directory signature not found.  Either this file is not
#   a zipfile, or it constitutes one disk of a multi-part archive.  In the
#   latter case the central directory and zipfile comment will be found on
#   the last disk(s) of this archive.
# unzip:  cannot find zipfile directory in one of folder.zip or
#         folder.zip.zip, and cannot find folder.zip.ZIP, period.

# %%
# !cd images/

# %%
# !ls
# Out:
# folder.zip  images
